# %%
import numpy as np
import pandas as pd
import matplotlib

 #50개의난수생성
data=np.random.rand(50)
print(type(data))
print(data)
# 넘파이배열을판다스의시리즈자료형으로변환(인덱스,데이터의조합)
seri=pd.Series(data)
print(type(seri))
print(seri)
seri.plot()
seri.plot.bar()
# Out:
# <class 'numpy.ndarray'>
# [0.72360911 0.32009378 0.83218309 0.86043607 0.986119   0.24592143
#  0.61447783 0.84596505 0.22737623 0.06075002 0.7008216  0.40792772
#  0.71589835 0.764879   0.70360686 0.99982969 0.13191951 0.92703791
#  0.1886492  0.44376281 0.00553598 0.93790936 0.99274544 0.7991961
#  0.76263451 0.8580229  0.54773879 0.50489465 0.30158471 0.69440238
#  0.54981581 0.04559066 0.93746057 0.69018606 0.55453302 0.53117957
#  0.41192215 0.16780314 0.16538708 0.778042   0.62564027 0.44265
#  0.7644221  0.19104824 0.6313965  0.49374874 0.56022407 0.1959091
#  0.76416767 0.70913892]
# <class 'pandas.core.series.Series'>
# 0     0.723609
# 1     0.320094
# 2     0.832183
# 3     0.860436
# 4     0.986119
# 5     0.245921
# 6     0.614478
# 7     0.845965
# 8     0.227376
# 9     0.060750
# 10    0.700822
# 11    0.407928
# 12    0.715898
# 13    0.764879
# 14    0.703607
# 15    0.999830
# 16    0.131920
# 17    0.927038
# 18    0.188649
# 19    0.443763
# 20    0.005536
# ...
